# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import mmdet, mmcv, mmengine
from mmengine.config import Config
from mmengine.runner import Runner
from mmdet.utils import register_all_modules
from mmdet.apis import init_detector, inference_detector
from mmengine.visualization import Visualizer

print(mmdet.__version__)
print(mmcv.__version__)
print(mmengine.__version__)
# Out:
# 3.1.0
# 2.0.1
# 0.8.2

# %%
width = 512
height = 512

max_epochs = 30

batch_size = 4
num_classes = 1

dataset_type = "CocoDataset"
classes = ('glomerulus') 
data_root = 'C:/Users/user/Desktop/HuBMAP/'

# %%
rtmdet_cfg_name = "../mmdetection/configs/rtmdet/rtmdet_x_8xb32-300e_coco.py"
rtmdet_cfg = Config.fromfile(rtmdet_cfg_name)

# %%
print(rtmdet_cfg.pretty_text)
# Out:
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=10, max_keep_ckpts=3),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# train_cfg = dict(
#     type='EpochBasedTrainLoop',
#     max_epochs=300,
#     val_interval=10,
#     dynamic_intervals=[
# ...
